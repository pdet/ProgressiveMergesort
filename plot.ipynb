# %%
import pandas as pd
import matplotlib.pyplot as plt

a = pd.read_csv("prog_idx.csv",delimiter=';')

# plt.plot([0.0055] * len(a), label='Full Scan') # y
plt.plot([0.20] * len(a), label='Interactive Threshold') # y

plt.plot(a['total_time'], label='Total Time')

# a.plot(kind='line',y='total_time',ax=ax, logy = True)
# a.plot(kind='line',y='total_time',ax=10, logy = True)

# df.plot(kind='line',x='name',y='num_pets', color='red', ax=ax)

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left',)
plt.yscale("log")

plt.show()
